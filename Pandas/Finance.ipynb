# %% [markdown]
# #### WHY PANDAS? - data cleansing, analysis, transformations
#     [Power Query + Pivot Tables + XL Formulae]
#
#   - load data remotely / connect up to a database
#   - work in exploratory manner with data
#   - clean, manipulate (slice and - divide ), reshape and combine data
#   - handle large datasets and use of dataframes
#   - plotting of the resulting dataset is possible

# %%
import pandas as pd
import numpy as np # alias

print(pd.__version__)  # 2.2.1
# Out:
# 2.2.1

# %% [markdown]
# ### Ways to create pandas Series :
#
# list_name = [1, 2, 3, 4,5]
#
# - s = pd.Series(list_name)
# - s = pd.Series(list_name, index=[1, 2, 3, 4, 5])
# - s = pd.Series(dictionary_name)
# - s = pd.Series(10, index = [1, 2, 3]) `Constant Series`
# - s = pd.Series(np.linspace(starting_number, end_number, items_number))
#
# ### Ways to create pandas Series :
#
# - df = pd.DataFrame(list_of_lists_name, columns=['Column_1_name','Column_2_name','Column_3_name'])
# - df = pd.DataFrame(dictionary_name)
# - df = pd.DataFrame(list_of_dictionaries_name)

# %%
df = pd.read_csv('Churn_Modelling.csv')
# pd.read_excel("",sheet_name="") pd.read_json pd.read_table, etc. are also there

# %%
# pd.set_option('display.max.rows',10000)
pd.reset_option('display.max.rows')

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df.head(10)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
# 5          6    15574012       Chu          645     Spain    Male   44
# 6          7    15592531  Bartlett          822    France    Male   50
# 7          8    15656148    Obinna          376   Germany  Female   29
# 8          9    15792365        He          501    France    Male   44
# 9         10    15592389        H?          684    France    Male   27
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# ...

# %%
df.tail()
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9995         96270.64       0
# 9996        101699.77       0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
df.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
df.T  # transpose
# Out:
#                       0          1          2         3          4     \
# RowNumber                1          2          3         4          5
# CustomerId        15634602   15647311   15619304  15701354   15737888
# Surname           Hargrave       Hill       Onio      Boni   Mitchell
# CreditScore            619        608        502       699        850
# Geography           France      Spain     France    France      Spain
# Gender              Female     Female     Female    Female     Female
# Age                     42         41         42        39         43
# Tenure                   2          1          8         1          2
# Balance                0.0   83807.86   159660.8       0.0  125510.82
# NumOfProducts            1          1          3         2          1
# HasCrCard                1          0          1         0          1
# IsActiveMember           1          1          0         0          1
# ...

# %%
df.sort_values('Age')
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 3512       3513    15657779       Boylan          806     Spain    Male   18
# 1678       1679    15569178    Kharlamov          570    France  Female   18
# 3517       3518    15757821      Burgess          771     Spain    Male   18
# 9520       9521    15673180  Onyekaozulu          727   Germany  Female   18
# 2021       2022    15795519     Vasiliev          716   Germany  Female   18
# ...         ...         ...          ...          ...       ...     ...  ...
# 3387       3388    15798024         Lori          537   Germany    Male   84
# 3033       3034    15578006          Yao          787    France  Female   85
# 2458       2459    15813303      Rearick          513     Spain    Male   88
# 6759       6760    15660878        T'ien          705    France    Male   92
# 6443       6444    15764927       Rogova          753    France    Male   92
#
# ...

# %%
df['Balance']  # print specific column OR..
# Out:
# 0            0.00
# 1        83807.86
# 2       159660.80
# 3            0.00
# 4       125510.82
#           ...
# 9995         0.00
# 9996     57369.61
# 9997         0.00
# 9998     75075.31
# 9999    130142.79
# Name: Balance, Length: 10000, dtype: float64

# %%
df.Balance
# Out:
# 0            0.00
# 1        83807.86
# 2       159660.80
# 3            0.00
# 4       125510.82
#           ...
# 9995         0.00
# 9996     57369.61
# 9997         0.00
# 9998     75075.31
# 9999    130142.79
# Name: Balance, Length: 10000, dtype: float64

# %%
df['Added Balance'] = df['Balance'] + 1000
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df['Random Column'] = 'Text Message'
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  Added Balance Random Column
# 0        101348.88       1        1000.00  Text Message
# ...

# %%
df[10:13]  # access rows
# Out:
#     RowNumber  CustomerId  Surname  CreditScore Geography  Gender  Age  \
# 10         11    15767821   Bearce          528    France    Male   31
# 11         12    15737173  Andrews          497     Spain    Male   24
# 12         13    15632264      Kay          476    France  Female   34
#
#     Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 10       6  102016.72              2          0               0
# 11       3       0.00              2          1               0
# 12      10       0.00              2          1               0
#
#     EstimatedSalary  Exited  Added Balance Random Column
# 10         80181.12       0      103016.72  Text Message
# 11         76390.01       0        1000.00  Text Message
# 12         26260.98       0        1000.00  Text Message

# %%
fifty_plus = df[df['Age'] > 50]  # SELECT * FROM df WHERE Age > 50

# %%
len(fifty_plus)
# Out:
# 1261

# %%
df['Age'].isna()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Name: Age, Length: 10000, dtype: bool

# %%
df.dropna() # drop null values
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df['Age'].fillna(100) # fill all null age values by 100
# Out:
# 0       42
# 1       41
# 2       42
# 3       39
# 4       43
#         ..
# 9995    39
# 9996    35
# 9997    36
# 9998    42
# 9999    28
# Name: Age, Length: 10000, dtype: int64

# %%
df.pop('Random Column') # remove columns
# Out:
# 0       Text Message
# 1       Text Message
# 2       Text Message
# 3       Text Message
# 4       Text Message
#             ...
# 9995    Text Message
# 9996    Text Message
# 9997    Text Message
# 9998    Text Message
# 9999    Text Message
# Name: Random Column, Length: 10000, dtype: object

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  Added Balance
# 0        101348.88       1        1000.00
# 1        112542.58       0       84807.86
# ...

# %%
fifty_plus_dropped = fifty_plus.drop('RowNumber',axis=1)  # axis, which is 1 (columns). This means it removes the 'RowNumber' column from the DataFrame.
fifty_plus_dropped.tail()
# Out:
#       CustomerId      Surname  CreditScore Geography  Gender  Age  Tenure  \
# 9936    15653037        Parks          609    France    Male   77       1
# 9939    15808971       Lajoie          693     Spain  Female   57       9
# 9948    15735078    Onwughara          724   Germany  Female   53       1
# 9979    15692664       Diribe          677    France  Female   58       1
# 9991    15769959  Ajuluchukwu          597    France  Female   53       4
#
#         Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 9936       0.00              1          0               1         18708.76
# 9939       0.00              2          1               1        135502.77
# 9948  139687.66              2          1               1         12913.92
# 9979   90022.85              1          0               1          2988.28
# 9991   88381.21              1          1               0         69384.71
#
#       Exited  Added Balance Random Column
# ...

# %%
df['SQRT Balance'] = df['Balance'].apply(np.sqrt)
# before I haven't written LHS, so action was performed in Balance, now after writing LHS, why values are like before in Balance?

# %%
pd.concat([df, df])  # union in SQL
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
left_merge = pd.merge(df, df, on='RowNumber', how="left") # 2n-1 columns
left_merge
# Out:
#       RowNumber  CustomerId_x  Surname_x  CreditScore_x Geography_x Gender_x  \
# 0             1      15634602   Hargrave            619      France   Female
# 1             2      15647311       Hill            608       Spain   Female
# 2             3      15619304       Onio            502      France   Female
# 3             4      15701354       Boni            699      France   Female
# 4             5      15737888   Mitchell            850       Spain   Female
# ...         ...           ...        ...            ...         ...      ...
# 9995       9996      15606229   Obijiaku            771      France     Male
# 9996       9997      15569892  Johnstone            516      France     Male
# 9997       9998      15584532        Liu            709      France   Female
# 9998       9999      15682355  Sabbatini            772     Germany     Male
# 9999      10000      15628319     Walker            792      France   Female
#
# ...

# %%
right_merge = pd.merge(df, df, on='RowNumber', how="right") # 2n-1 columns
right_merge
# Out:
#       RowNumber  CustomerId_x  Surname_x  CreditScore_x Geography_x Gender_x  \
# 0             1      15634602   Hargrave            619      France   Female
# 1             2      15647311       Hill            608       Spain   Female
# 2             3      15619304       Onio            502      France   Female
# 3             4      15701354       Boni            699      France   Female
# 4             5      15737888   Mitchell            850       Spain   Female
# ...         ...           ...        ...            ...         ...      ...
# 9995       9996      15606229   Obijiaku            771      France     Male
# 9996       9997      15569892  Johnstone            516      France     Male
# 9997       9998      15584532        Liu            709      France   Female
# 9998       9999      15682355  Sabbatini            772     Germany     Male
# 9999      10000      15628319     Walker            792      France   Female
#
# ...

# %% [markdown]
# loc - rows (and/or columns) with labels
# iloc - rows (and/or columns) at integer location

# %%
s1 = pd.Series(list("abcdef"), index=[49,48,47,0,1,2])
s1
# Out:
# 49    a
# 48    b
# 47    c
# 0     d
# 1     e
# 2     f
# dtype: object

# %%
s1.loc[0] # value at index label/value 0 - inclusive
# Out:
# 'd'

# %%
s1.iloc[0] # value at index location 0 - exclusive
# Out:
# 'a'

# %%
s1.iloc[1:3] # value at index location 0
# Out:
# 48    b
# 47    c
# dtype: object

# %%
df['Surname'].dtype
# Out:
# dtype('O')

# %%
df[df['Geography'].isin(['France', 'Spain'])]
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9994       9995    15719294       Wood          800    France  Female   29
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.set_index('Geography')
# Out:
#            RowNumber  CustomerId    Surname  CreditScore  Gender  Age  Tenure  \
# Geography
# France             1    15634602   Hargrave          619  Female   42       2
# Spain              2    15647311       Hill          608  Female   41       1
# France             3    15619304       Onio          502  Female   42       8
# France             4    15701354       Boni          699  Female   39       1
# Spain              5    15737888   Mitchell          850  Female   43       2
# ...              ...         ...        ...          ...     ...  ...     ...
# France          9996    15606229   Obijiaku          771    Male   39       5
# France          9997    15569892  Johnstone          516    Male   35      10
# France          9998    15584532        Liu          709  Female   36       7
# Germany         9999    15682355  Sabbatini          772    Male   42       3
# France         10000    15628319     Walker          792  Female   28       4
#
# ...

# %%
df.filter(items=["Geography","Age"])
# Out:
#      Geography  Age
# 0       France   42
# 1        Spain   41
# 2       France   42
# 3       France   39
# 4        Spain   43
# ...        ...  ...
# 9995    France   39
# 9996    France   35
# 9997    France   36
# 9998   Germany   42
# 9999    France   28
#
# [10000 rows x 2 columns]

# %%
df[df['Age']<40].sort_values(by="Tenure", ascending=True)
# Out:
#       RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 8213       8214    15748352  Endrizzi          598     Spain    Male   34
# 4704       4705    15754113        Li          588    France  Female   35
# 4702       4703    15661007  Thompson          660    France    Male   33
# 4700       4701    15773709      Hung          838     Spain    Male   35
# 8085       8086    15656286      Sims          794    France    Male   33
# ...         ...         ...       ...          ...       ...     ...  ...
# 6980       6981    15748360     Cocci          644   Germany  Female   34
# 829         830    15639788      Yuan          577    France  Female   39
# 5065       5066    15775709     Nucci          832    France  Female   27
# 3075       3076    15594577   De Luca          556    France    Male   35
# 7002       7003    15687688       Hou          564   Germany  Female   32
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.reset_index(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2792\136303746.py in ?()
# ----> 1 df.reset_index(inplace=True)
#
# c:\Users\adity\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py in ?(self, level, drop, inplace, col_level, col_fill, allow_duplicates, names)
#    6455                     level_values = algorithms.take(
#    6456                         level_values, lab, allow_fill=True, fill_value=lev._na_value
#    6457                     )
#    6458
# -> 6459                 new_obj.insert(
#    6460                     0,
#    6461                     name,
#    6462                     level_values,
#
# c:\Users\adity\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py in ?(self, loc, column, value, allow_duplicates)
# ...

# %%
df.groupby('CreditScore').agg({'Age':['mean', 'max', 'count', 'sum']})
# Out:
#                    Age
#                   mean max count   sum
# CreditScore
# 350          48.800000  60     5   244
# 351          57.000000  57     1    57
# 358          52.000000  52     1    52
# 359          44.000000  44     1    44
# 363          28.000000  28     1    28
# ...                ...  ..   ...   ...
# 846          42.200000  61     5   211
# 847          43.500000  66     6   261
# 848          33.600000  40     5   168
# 849          42.500000  69     8   340
# 850          38.918455  81   233  9068
#
# [460 rows x 4 columns]

# %%
group_by_CreditScore = df.groupby('CreditScore')

# %%
group_by_CreditScore.count()
# Out:
#              level_0  index  RowNumber  CustomerId  Surname  Geography  \
# CreditScore
# 350                5      5          5           5        5          5
# 351                1      1          1           1        1          1
# 358                1      1          1           1        1          1
# 359                1      1          1           1        1          1
# 363                1      1          1           1        1          1
# ...              ...    ...        ...         ...      ...        ...
# 846                5      5          5           5        5          5
# 847                6      6          6           6        6          6
# 848                5      5          5           5        5          5
# 849                8      8          8           8        8          8
# 850              233    233        233         233      233        233
#
#              Gender  Age  Tenure  Balance  NumOfProducts  HasCrCard  \
# CreditScore
# ...

# %%
df.groupby('CreditScore')["Age"].mean()  #45:00
# Out:
# CreditScore
# 350    48.800000
# 351    57.000000
# 358    52.000000
# 359    44.000000
# 363    28.000000
#          ...
# 846    42.200000
# 847    43.500000
# 848    33.600000
# 849    42.500000
# 850    38.918455
# Name: Age, Length: 460, dtype: float64
