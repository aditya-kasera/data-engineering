# %%
import pandas as pd

# %%
df = pd.read_csv('Employees.csv')
df.head()
# Out:
#   first_name last_name                department  \
# 0   Carmelia    Atcock                     Sales
# 1     Lorine   Chattoe           Human Resources
# 2     Isiahi  Scholtis  Research and Development
# 3      Hardy  Roglieri                  Training
# 4  Jacquette     Duffy               Engineering
#
#                              email    salary
# 0  catcock0@scientificamerican.com       NaN
# 1        lchattoe1@hugedomains.com       NaN
# 2       ischoltis2@accuweather.com     94297
# 3           hroglieri3@squidoo.com       NaN
# 4            jduffy4@shinystat.com  365-0023

# %%
grouped_by_department = df.groupby('department')['salary']
grouped_dataframe = pd.DataFrame(grouped_by_department.count())
grouped_dataframe  # df grouped by department with no. of salaries
# Out:
#                           salary
# department
# Accounting                     9
# Business Development           9
# Engineering                    7
# Human Resources               10
# Legal                          6
# Marketing                     10
# Product Management             9
# Research and Development      10
# Sales                          4
# Services                      11
# Support                        1
# Training                       9

# %%
df.sort_values(by='salary',ascending=True) # df sorted by salaries
# Out:
#     first_name  last_name            department                        email  \
# 108      Rolph    Brouwer       Human Resources     rbrouwer30@quantcast.com
# 52       Gabie    Titford              Services     gtitford1g@csmonitor.com
# 39    Alistair     Wisher             Marketing        awisher13@histats.com
# 165    Wilburt   Kornacki            Accounting        wkornacki4l@unblog.fr
# 42      Joanne     McEwan  Business Development        jmcewan16@sina.com.cn
# ..         ...        ...                   ...                          ...
# 191    Jasmina    D'Elias            Accounting      jdelias5b@wordpress.org
# 192     Alyson    Jouning               Support      ajouning5c@amazon.co.uk
# 193       Esme    Coaster           Engineering       ecoaster5d@myspace.com
# 195    Christa       Tite              Training           ctite5f@amazon.com
# 199      Ollie  Dovydenas               Support  odovydenas5j@techcrunch.com
#
#         salary
# 108       0492
# ...
